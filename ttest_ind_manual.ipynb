# %%
from scipy import stats
import numpy as np

# %%
np.random.seed(12345678)

# %%
x1 = stats.norm.rvs(loc=5,scale=10,size=500)
x2 = stats.norm.rvs(loc=5,scale=10,size=500)
stats.ttest_ind(x1,x2)
# Out:
# Ttest_indResult(statistic=-0.1752303262355214, pvalue=0.8609342004015923)

# %%
t = (x1.mean() - x2.mean() ) / np.sqrt( (x1.std()**2 / len(x1)) + (x2.std()**2 / len(x2)) )
t
# Out:
# -0.17540581984609011
