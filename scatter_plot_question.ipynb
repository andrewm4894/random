# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import data (PP-2016) into pandas
pp2016 = pd.read_csv('C:\\Users\\Andrew\\Documents\\Python\\SpringBoard\\random\\scatter_question\\pp-2016-sample.csv', index_col = None)
# Replace NaN with Blank
pp2016 = pp2016.fillna('')
print pp2016.shape
pp2016.head()
# Out:
# (46022, 16)
#             Transaction Unique Identifier  Sale Price Date Of Transfer  \
# 0  {39140479-D3AC-3206-E050-A8C063057647}       68000   5/20/2016 0:00
# 1  {39140479-D3AD-3206-E050-A8C063057647}      212000    6/9/2016 0:00
# 2  {39140479-D3AE-3206-E050-A8C063057647}      105000   6/21/2016 0:00
# 3  {39140479-D3AF-3206-E050-A8C063057647}      125000    6/6/2016 0:00
# 4  {39140479-D3B0-3206-E050-A8C063057647}      176000   6/10/2016 0:00
#
#   Postcode Property Type Is New Duration PAON SAON            Street  \
# 0  BB5 0HJ             T      N        F   75        LONSDALE STREET
# 1  BB5 3AN             D      N        L    6             LARCH ROAD
# 2  LA3 2TP             T      N        F    6       HEATHFOOT AVENUE
# 3  BB4 4EF             S      N        L  102             RYDAL ROAD
# 4  BB6 7HJ             S      N        F   15                BOSTONS
#
#         Locality        Town    District      County PPD Category Type  \
# ...

# %%
# get a sample
pp2016_sample = pp2016.sample(n=5000)

# %%
plt.figure(figsize=(10,10))
# Draw a categorical scatterplot to show each observation
sns.swarmplot(y="District", x="Sale Price", hue="County", data=pp2016_sample)
