# %%
import json
import pandas as pd

# %%
tweets = []
for line in open('tweets.json', 'r'):
    tweets.append(json.loads(line))

# %%
df_tweets = pd.DataFrame.from_dict(tweets)
print(df_tweets.shape)
df_tweets.head(2)
# Out:
# (1118, 36)
#   contributors coordinates                      created_at display_text_range  \
# 0         None        None  Tue Sep 24 03:24:13 +0000 2019                NaN
# 1         None        None  Tue Sep 24 03:24:16 +0000 2019          [15, 140]
#
#                                             entities  \
# 0  {'hashtags': [{'text': 'TDR_now', 'indices': [...
# 1  {'hashtags': [], 'urls': [{'url': 'https://t.c...
#
#                                    extended_entities  \
# 0  {'media': [{'id': 1176330997974982657, 'id_str...
# 1                                                NaN
#
#                                       extended_tweet  favorite_count  \
# 0                                                NaN               0
# 1  {'full_text': '@OrangeGrove55 Galaxy’s Edge at...               0
#
#    favorited filter_level  ... quoted_status_permalink  reply_count  \
# 0      False          low  ...                     NaN            0
# 1      False          low  ...                     NaN            0
#
#   retweet_count retweeted                                   retweeted_status  \
# 0             0     False  {'created_at': 'Tue Sep 24 03:02:22 +0000 2019...
# 1             0     False                                                NaN
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text   timestamp_ms  \
# 0  RT @tdrblognote: これが新しいミッキー花壇ですか～ 分離型です。イベントフォ...  1569295453815
# 1  @OrangeGrove55 Galaxy’s Edge at Walt Disney Wo...  1569295456293
#
#    truncated                                               user
# 0      False  {'id': 2228171312, 'id_str': '2228171312', 'na...
# 1       True  {'id': 286969280, 'id_str': '286969280', 'name...
#
# [2 rows x 36 columns]

# %%
# just normalise the nested json col on its own into a df
df_retweeted_status = pd.DataFrame(df_tweets['retweeted_status'].to_dict()).transpose()
# add in id based on common index position
df_retweeted_status = df_tweets[['id']].merge(df_retweeted_status,'inner',left_index=True,right_index=True,suffixes=('_df_tweets', ''))

# look at data
print(df_retweeted_status.shape)
df_retweeted_status.head()
# Out:
# (1118, 36)
#           id_df_tweets contributors coordinates  \
# 0  1176336509575712768         None        None
# 1  1176336519969345536          NaN         NaN
# 2  1176336531339919360         None        None
# 3  1176336557969567744         None        None
# 4  1176336572305874944          NaN         NaN
#
#                        created_at display_text_range  \
# 0  Tue Sep 24 03:02:22 +0000 2019            [0, 83]
# 1                             NaN                NaN
# 2  Tue Sep 24 00:36:50 +0000 2019            [0, 42]
# 3  Tue Sep 24 00:47:20 +0000 2019           [0, 106]
# 4                             NaN                NaN
#
#                                             entities  \
# 0  {'hashtags': [{'text': 'TDR_now', 'indices': [...
# 1                                                NaN
# 2  {'hashtags': [{'text': 'TDR_now', 'indices': [...
# 3  {'hashtags': [{'text': 'Halloween', 'indices':...
# 4                                                NaN
#
#                                    extended_entities extended_tweet  \
# 0  {'media': [{'id': 1176330997974982657, 'id_str...            NaN
# 1                                                NaN            NaN
# 2  {'media': [{'id': 1176294370477142021, 'id_str...            NaN
# 3  {'media': [{'id': 1176297011596972032, 'id_str...            NaN
# 4                                                NaN            NaN
#
#   favorite_count favorited  ... quoted_status_id_str quoted_status_permalink  \
# 0             11     False  ...                  NaN                     NaN
# 1            NaN       NaN  ...                  NaN                     NaN
# 2            105     False  ...                  NaN                     NaN
# 3             10     False  ...                  NaN                     NaN
# 4            NaN       NaN  ...                  NaN                     NaN
#
#   reply_count retweet_count retweeted scopes  \
# 0           0             9     False    NaN
# 1         NaN           NaN       NaN    NaN
# 2           0            44     False    NaN
# 3           0             4     False    NaN
# 4         NaN           NaN       NaN    NaN
#
#                                               source  \
# 0  <a href="https://github.com/TwidereProject" re...
# 1                                                NaN
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="https://mobile.twitter.com" rel="nofo...
# 4                                                NaN
#
#                                                 text truncated  \
# 0  これが新しいミッキー花壇ですか～ 分離型です。イベントフォトロケを作るなら、ワールドバザール...     False
# 1                                                NaN       NaN
# 2  昨日となんか違うと思ったら\nミッキー花壇帰ってました！\nお帰り！\n\n#TDR_now...     False
# 3  New #Halloween themed cups! #ShanghaiDisneylan...     False
# 4                                                NaN       NaN
#
#                                                 user
# 0  {'id': 109227124, 'id_str': '109227124', 'name...
# 1                                                NaN
# 2  {'id': 731025834601930752, 'id_str': '73102583...
# 3  {'id': 701695726279995392, 'id_str': '70169572...
# 4                                                NaN
#
# [5 rows x 36 columns]
