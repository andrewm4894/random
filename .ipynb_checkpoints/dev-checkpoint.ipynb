# %%
import requests

# %%
import requests
res = requests.get('https://prettyprinted.com')
with open('dev.txt', "w", encoding="utf-8") as f:
    f.write(res.text)

# %%
with open('dev.txt', "w", encoding="utf-8") as f:
    f.write(res.text)
